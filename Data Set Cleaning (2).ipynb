# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data Cleaning 12.08.csv")

# %%
df.head()
# Out:
#         name planet_status   mass  mass_error_min  mass_error_max  mass_sini  \
# 0  109 Psc b     Confirmed  5.743           0.289           1.011     6.3830
# 1  112 Psc b     Confirmed    NaN           0.005           0.004     0.0330
# 2  112 Psc c     Confirmed  9.866           1.781           3.190        NaN
# 3   11 UMi b     Confirmed    NaN           1.100           1.100    11.0873
# 4  14 And Ab     Confirmed    NaN           0.230           0.230     4.6840
#
#    mass_sini_error_min  mass_sini_error_max  radius  radius_error_min
# 0                0.078                0.078   1.152               NaN
# 1                0.005                0.004     NaN               NaN
# 2                  NaN                  NaN     NaN               NaN
# 3                1.100                1.100     NaN               NaN
# 4                0.230                0.230     NaN               NaN

# %%
raw_df = df.copy()

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 5986
# Number of columns: 10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5986 entries, 0 to 5985
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 5986 non-null   object
#  1   planet_status        5986 non-null   object
#  2   mass                 2079 non-null   float64
#  3   mass_error_min       2817 non-null   float64
#  4   mass_error_max       2817 non-null   float64
#  5   mass_sini            1202 non-null   float64
#  6   mass_sini_error_min  1039 non-null   float64
#  7   mass_sini_error_max  1039 non-null   float64
#  8   radius               5986 non-null   float64
#  9   radius_error_min     4093 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 467.8+ KB

# %%
df.head()
# Out:
#         name planet_status   mass  mass_error_min  mass_error_max  mass_sini  \
# 0  109 Psc b     Confirmed  5.743           0.289           1.011     6.3830
# 1  112 Psc b     Confirmed    NaN           0.005           0.004     0.0330
# 2  112 Psc c     Confirmed  9.866           1.781           3.190        NaN
# 3   11 UMi b     Confirmed    NaN           1.100           1.100    11.0873
# 4  14 And Ab     Confirmed    NaN           0.230           0.230     4.6840
#
#    mass_sini_error_min  mass_sini_error_max  radius  radius_error_min
# 0                0.078                0.078   1.152               NaN
# 1                0.005                0.004   0.219               NaN
# 2                  NaN                  NaN   0.219               NaN
# 3                1.100                1.100   0.219               NaN
# 4                0.230                0.230   0.219               NaN

# %%
df.tail()
# Out:
#            name planet_status  mass  mass_error_min  mass_error_max  \
# 5981  YBP 401 b     Confirmed   NaN         0.05000         0.05000
# 5982   YSES 2 b     Confirmed   6.3         0.90000         1.60000
# 5983   YZ Cet b     Confirmed   NaN         0.00028         0.00028
# 5984   YZ Cet c     Confirmed   NaN         0.00035         0.00035
# 5985   YZ Cet d     Confirmed   NaN         0.00038         0.00038
#
#       mass_sini  mass_sini_error_min  mass_sini_error_max  radius  \
# 5981    0.46000              0.05000              0.05000   0.219
# 5982        NaN                  NaN                  NaN   0.219
# 5983    0.00220              0.00028              0.00028   0.219
# 5984    0.00359              0.00035              0.00035   0.219
# 5985    0.00343              0.00038              0.00038   0.219
#
#       radius_error_min
# 5981               NaN
# 5982               NaN
# 5983               NaN
# 5984               NaN
# 5985               NaN

# %%
df.columns.tolist()
# Out:
# ['name',
#  'planet_status',
#  'mass',
#  'mass_error_min',
#  'mass_error_max',
#  'mass_sini',
#  'mass_sini_error_min',
#  'mass_sini_error_max',
#  'radius',
#  'radius_error_min']

# %%
df.columns
# Out:
# Index(['name', 'planet_status', 'mass', 'mass_error_min', 'mass_error_max',
#        'mass_sini', 'mass_sini_error_min', 'mass_sini_error_max', 'radius',
#        'radius_error_min'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name                    object
# planet_status           object
# mass                   float64
# mass_error_min         float64
# mass_error_max         float64
# mass_sini              float64
# mass_sini_error_min    float64
# mass_sini_error_max    float64
# radius                 float64
# radius_error_min       float64
# dtype: object

# %%
df.describe()
# Out:
#               mass  mass_error_min  mass_error_max    mass_sini  \
# count  2079.000000     2817.000000       2817.0000  1202.000000
# mean      1.492538        0.324366             inf     1.983529
# std       2.602286        1.351929             NaN     3.199717
# min       0.000190        0.000000        -17.8000     0.000470
# 25%       0.029655        0.006290          0.0057     0.045000
# 50%       0.370000        0.041000          0.0400     0.731500
# 75%       1.466500        0.170000          0.1700     2.400000
# max      12.934000       53.500000             inf    50.000000
#
#        mass_sini_error_min  mass_sini_error_max       radius  radius_error_min
# count          1039.000000          1039.000000  5986.000000       4093.000000
# mean              0.214687             0.240453     0.358280          0.048986
# std               0.636474             0.945468     0.384070          0.754220
# ...

# %%
df.describe(include="object")
# Out:
#              name planet_status
# count        5986          5986
# unique       5986             1
# top     109 Psc b     Confirmed
# freq            1          5986

# %%
missing_count = df.isnull().sum()

missing_count
# Out:
# name                      0
# planet_status             0
# mass                   3907
# mass_error_min         3169
# mass_error_max         3169
# mass_sini              4784
# mass_sini_error_min    4947
# mass_sini_error_max    4947
# radius                    0
# radius_error_min       1893
# dtype: int64

# %%
plt.figure(figsize=(12,6))

sns.heatmap(
    df.isnull(),
    cbar=False
)

plt.title("Missing Value Heatmap")
plt.show()

# %%
missing_percentage
# Out:
# name                    0.000000
# planet_status           0.000000
# mass                   65.268961
# mass_error_min         52.940194
# mass_error_max         52.940194
# mass_sini              79.919813
# mass_sini_error_min    82.642833
# mass_sini_error_max    82.642833
# radius                 23.688607
# radius_error_min       31.623789
# dtype: float64

# %%
duplicate_count = df.duplicated().sum()

print("Duplicate records:", duplicate_count)
# Out:
# Duplicate records: 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [name, planet_status, mass, mass_error_min, mass_error_max, mass_sini, mass_sini_error_min, mass_sini_error_max, radius, radius_error_min]
# Index: []

# %%
df = df.drop_duplicates().copy()

# %%
print("Duplicates after cleaning:", df.duplicated().sum())
# Out:
# Duplicates after cleaning: 0

# %%
df["name"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["planet_status"].value_counts(dropna=False)
# Out:
# planet_status
# Confirmed    5986
# Name: count, dtype: int64

# %%
df["planet_status"] = df["planet_status"].str.strip()

# %%
df["planet_status"] = df["planet_status"].str.title()

# %%
df["planet_status"].value_counts()
# Out:
# planet_status
# Confirmed    5986
# Name: count, dtype: int64

# %%
df["planet_status"].unique()
# Out:
# array(['Confirmed'], dtype=object)

# %%
numeric_columns = df.select_dtypes(include=np.number).columns

numeric_columns
# Out:
# Index(['mass', 'mass_error_min', 'mass_error_max', 'mass_sini',
#        'mass_sini_error_min', 'mass_sini_error_max', 'radius',
#        'radius_error_min'],
#       dtype='object')

# %%
df[numeric_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5986 entries, 0 to 5985
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   mass                 2079 non-null   float64
#  1   mass_error_min       2817 non-null   float64
#  2   mass_error_max       2817 non-null   float64
#  3   mass_sini            1202 non-null   float64
#  4   mass_sini_error_min  1039 non-null   float64
#  5   mass_sini_error_max  1039 non-null   float64
#  6   radius               5986 non-null   float64
#  7   radius_error_min     4093 non-null   float64
# dtypes: float64(8)
# memory usage: 374.3 KB

# %%
(df[numeric_columns] < 0).sum()
# Out:
# mass                   0
# mass_error_min         0
# mass_error_max         1
# mass_sini              0
# mass_sini_error_min    0
# mass_sini_error_max    0
# radius                 0
# radius_error_min       0
# dtype: int64

# %%
df[df["mass"] < 0]
# Out:
# Empty DataFrame
# Columns: [name, planet_status, mass, mass_error_min, mass_error_max, mass_sini, mass_sini_error_min, mass_sini_error_max, radius, radius_error_min]
# Index: []

# %%
df[df["radius"] < 0]
# Out:
# Empty DataFrame
# Columns: [name, planet_status, mass, mass_error_min, mass_error_max, mass_sini, mass_sini_error_min, mass_sini_error_max, radius, radius_error_min]
# Index: []

# %%
df.loc[df["mass"] < 0, "mass"] = np.nan
df.loc[df["radius"] < 0, "radius"] = np.nan

# %%
(df[numeric_columns] == 0).sum()
# Out:
# mass                    0
# mass_error_min          9
# mass_error_max         89
# mass_sini               0
# mass_sini_error_min     2
# mass_sini_error_max     8
# radius                  0
# radius_error_min        4
# dtype: int64

# %%
np.isinf(df[numeric_columns]).sum()
# Out:
# mass                   0
# mass_error_min         0
# mass_error_max         9
# mass_sini              0
# mass_sini_error_min    0
# mass_sini_error_max    0
# radius                 0
# radius_error_min       0
# dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x=df["mass"])

plt.title("Boxplot of Planetary Mass")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x=df["radius"])

plt.title("Boxplot of Planetary Radius")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["mass"].dropna(), kde=True)

plt.title("Distribution of Planetary Mass")
plt.xlabel("Mass")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["radius"].dropna(), kde=True)

plt.title("Distribution of Planetary Radius")
plt.xlabel("Radius")
plt.ylabel("Frequency")

plt.show()

# %%
df[numeric_columns].describe().T
# Out:
#                       count      mean       std       min       25%     50%  \
# mass                 2079.0  1.492538  2.602286   0.00019  0.029655  0.3700
# mass_error_min       2817.0  0.324366  1.351929   0.00000  0.006290  0.0410
# mass_error_max       2817.0       inf       NaN -17.80000  0.005700  0.0400
# mass_sini            1202.0  1.983529  3.199717   0.00047  0.045000  0.7315
# mass_sini_error_min  1039.0  0.214687  0.636474   0.00000  0.005940  0.0493
# mass_sini_error_max  1039.0  0.240453  0.945468   0.00000  0.005300  0.0500
# radius               5986.0  0.358280  0.384070   0.02543  0.168065  0.2190
# radius_error_min     4093.0  0.048986  0.754220   0.00000  0.010000  0.0200
#
#                         75%     max
# mass                 1.4665  12.934
# mass_error_min       0.1700  53.500
# mass_error_max       0.1700     inf
# mass_sini            2.4000  50.000
# mass_sini_error_min  0.1700  13.000
# mass_sini_error_max  0.1700  20.900
# ...

# %%
central_tendency = pd.DataFrame({
    "Mean": df[numeric_columns].mean(),
    "Median": df[numeric_columns].median(),
    "Mode": df[numeric_columns].mode().iloc[0]
})

central_tendency
# Out:
#                          Mean  Median   Mode
# mass                 1.492538  0.3700  0.800
# mass_error_min       0.324366  0.0410  0.100
# mass_error_max            inf  0.0400  0.000
# mass_sini            1.983529  0.7315  1.900
# mass_sini_error_min  0.214687  0.0493  0.200
# mass_sini_error_max  0.240453  0.0500  0.050
# radius               0.358280  0.2190  0.219
# radius_error_min     0.048986  0.0200  0.009

# %%
correlation_matrix = df[numeric_columns].corr()

correlation_matrix
# Out:
#                          mass  mass_error_min  mass_error_max  mass_sini  \
# mass                 1.000000        0.448574        0.101506   0.875983
# mass_error_min       0.448574        1.000000        0.021282   0.227523
# mass_error_max       0.101506        0.021282        1.000000   0.235206
# mass_sini            0.875983        0.227523        0.235206   1.000000
# mass_sini_error_min  0.407137        0.365126        0.463934   0.436514
# mass_sini_error_max  0.418206        0.263690        0.657367   0.370989
# radius               0.073953       -0.026458       -0.015572   0.029122
# radius_error_min     0.012419        0.003687        0.001831   0.149673
#
#                      mass_sini_error_min  mass_sini_error_max    radius  \
# mass                            0.407137             0.418206  0.073953
# mass_error_min                  0.365126             0.263690 -0.026458
# mass_error_max                  0.463934             0.657367 -0.015572
# ...

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Matrix")
plt.show()

# %%
df["planet_status"].value_counts()
# Out:
# planet_status
# Confirmed    5986
# Name: count, dtype: int64

# %%
df["planet_status"].value_counts(normalize=True) * 100
# Out:
# planet_status
# Confirmed    100.0
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,5))

sns.countplot(data=df, x="planet_status")

plt.title("Distribution of Planet Status")
plt.xlabel("Planet Status")
plt.ylabel("Count")

plt.show()

# %%
correlation_data = df[["mass", "radius"]].dropna()

# %%
df.shape
# Out:
# (5986, 10)

# %%
df.isnull().sum()
# Out:
# name                      0
# planet_status             0
# mass                   3907
# mass_error_min         3169
# mass_error_max         3169
# mass_sini              4784
# mass_sini_error_min    4947
# mass_sini_error_max    4947
# radius                    0
# radius_error_min       1893
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# name                    object
# planet_status           object
# mass                   float64
# mass_error_min         float64
# mass_error_max         float64
# mass_sini              float64
# mass_sini_error_min    float64
# mass_sini_error_max    float64
# radius                 float64
# radius_error_min       float64
# dtype: object

# %%
np.isinf(df.select_dtypes(include=np.number)).sum()
# Out:
# mass                   0
# mass_error_min         0
# mass_error_max         9
# mass_sini              0
# mass_sini_error_min    0
# mass_sini_error_max    0
# radius                 0
# radius_error_min       0
# dtype: int64

# %%
(df[["mass", "radius"]] < 0).sum()
# Out:
# mass      0
# radius    0
# dtype: int64

# %%
df["planet_status"].value_counts()
# Out:
# planet_status
# Confirmed    5986
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#               mass  mass_error_min  mass_error_max    mass_sini  \
# count  2079.000000     2817.000000       2817.0000  1202.000000
# mean      1.492538        0.324366             inf     1.983529
# std       2.602286        1.351929             NaN     3.199717
# min       0.000190        0.000000        -17.8000     0.000470
# 25%       0.029655        0.006290          0.0057     0.045000
# 50%       0.370000        0.041000          0.0400     0.731500
# 75%       1.466500        0.170000          0.1700     2.400000
# max      12.934000       53.500000             inf    50.000000
#
#        mass_sini_error_min  mass_sini_error_max       radius  radius_error_min
# count          1039.000000          1039.000000  5986.000000       4093.000000
# mean              0.214687             0.240453     0.358280          0.048986
# std               0.636474             0.945468     0.384070          0.754220
# ...

# %%
print("Original shape:", raw_df.shape)
print("Cleaned shape:", df.shape)

print("Original duplicates:", raw_df.duplicated().sum())
print("Cleaned duplicates:", df.duplicated().sum())
# Out:
# Original shape: (5986, 10)
# Cleaned shape: (5986, 10)
# Original duplicates: 0
# Cleaned duplicates: 0

# %%
comparison = pd.DataFrame({
    "Original Missing": raw_df.isnull().sum(),
    "Cleaned Missing": df.isnull().sum()
})

comparison
# Out:
#                      Original Missing  Cleaned Missing
# name                                0                0
# planet_status                       0                0
# mass                             3907             3907
# mass_error_min                   3169             3169
# mass_error_max                   3169             3169
# mass_sini                        4784             4784
# mass_sini_error_min              4947             4947
# mass_sini_error_max              4947             4947
# radius                              0                0
# radius_error_min                 1893             1893

# %%
df.to_csv(
    "cleaned_exoplanet_dataset.csv",
    index=False
)

# %%
cleaned_df = pd.read_csv("cleaned_exoplanet_dataset.csv")

cleaned_df.head()
# Out:
#         name planet_status   mass  mass_error_min  mass_error_max  mass_sini  \
# 0  109 Psc b     Confirmed  5.743           0.289           1.011     6.3830
# 1  112 Psc b     Confirmed    NaN           0.005           0.004     0.0330
# 2  112 Psc c     Confirmed  9.866           1.781           3.190        NaN
# 3   11 UMi b     Confirmed    NaN           1.100           1.100    11.0873
# 4  14 And Ab     Confirmed    NaN           0.230           0.230     4.6840
#
#    mass_sini_error_min  mass_sini_error_max  radius  radius_error_min
# 0                0.078                0.078   1.152               NaN
# 1                0.005                0.004   0.219               NaN
# 2                  NaN                  NaN   0.219               NaN
# 3                1.100                1.100   0.219               NaN
# 4                0.230                0.230   0.219               NaN

# %%
cleaned_df.shape
# Out:
# (5986, 10)

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5986 entries, 0 to 5985
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 5986 non-null   object
#  1   planet_status        5986 non-null   object
#  2   mass                 2079 non-null   float64
#  3   mass_error_min       2817 non-null   float64
#  4   mass_error_max       2817 non-null   float64
#  5   mass_sini            1202 non-null   float64
#  6   mass_sini_error_min  1039 non-null   float64
#  7   mass_sini_error_max  1039 non-null   float64
#  8   radius               5986 non-null   float64
#  9   radius_error_min     4093 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 467.8+ KB
